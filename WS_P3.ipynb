# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import re

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_colwidth',100)
pd.set_option('display.max_rows',None)

# %% [markdown]
# # Mais Lidos

# %%
url_mais_lidos = 'https://www.skoob.com.br/livro/top_mais/lidos/'
response_mais_lidos = requests.get(url_mais_lidos)
html_mais_lidos = response_mais_lidos.content
soup_mais_lidos = BeautifulSoup(html_mais_lidos)

# %%
print(soup_mais_lidos.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns="//www.w3.org/1999/xhtml">
#  <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# books: http://ogp.me/ns/books#">
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Top Mais lidos no SKOOB.
#   </title>
#   <meta content="pt-br" name="language"/>
#   <meta content="h_F9-djAws40JfpX_W4juzsPjd9YZ2v-s0YvOG-D388" name="google-site-verification"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="app-id=904670263" name="apple-itunes-app"/>
#   <meta content="app-id=com.gaudium.skoob" name="google-play-app"/>
#   <meta content="none" name="msapplication-config"/>
#   <meta content="22240835" name="lomadee-verification"/>
#   <script src="https://www.skoob.com.br/js/angularjs/base.min.js?1637270067" type="text/javascript">
#   </script>
#   <script src="https://www.skoob.com.br/js/angularjs/main.min.js?1639030176" type="text/javascript">
#   </script>
#   <link href="https://www.skoob.com.br/css/ver2/main.min.css?1639030170" rel="stylesheet" type="text/css"/>
#   <link href="https://www.skoob.com.br/css/dist-final-2019/geral.min.css?1637268866" rel="stylesheet" type="text/css"/>
#   <link href="https://www.skoob.com.br/css/dist-final-2019/livro/edicaoversao.min.css?1637268867" rel="stylesheet" type="text/css"/>
#  </head>
#  <body id="ng-app" ng-app="skoob">
#   <div>
#    <div class="navbar navbar-fixed-top" id="topo" style="height:48px;">
#     <div class="container" id="topoInterno" style="">
#      <a href="/">
#       <img alt="logo Skoob" class="logo" height="33" src="https://static-sp.skoob.com.br/img/v2/base/skoob-logo-topo.gif" title="logo Skoob" width="109"/>
#      </a>
#      <div data-ng-controller="SearchCtrl" data-ng-mouseleave="leave = true" id="tbusca">
#       <form action="/livro/lista/" class="form-inline" id="topo-menu-search" method="post">
#        <span class="busca-loading-container" data-ng-bind="search_total | numberDecimal" data-ng-cloak="" data-ng-show="search_total &gt; 0">
#        </span>
#        <div data-ng-cloak="" data-ng-show="search_loading" id="suggestions_loadingmessage">
#         <img alt="loading" src="//static-sp.skoob.com.br/img/v2/base/load-padrao.gif"/>
#        </div>
#        <div class="input-append">
#         <input autocomplete="off" class="form-control" data-ng-blur="searchExit()" data-ng-model="busca" id="search" name="data[Busca][tag]" placeholder="Busque por título, autor, editora, ISBN..." type="text"/>
#         <span class="input-group-btn">
#          <button class="btn btn-default btn-form-lupa" type="submit">
#           <i class="fa fa-search">
#           </i>
#          </button>
#         </span>
#        </div>
#       </form>
#       <div data-ng-cloak="" data-ng-mouseover="leave = false" data-ng-show="search_result" id="suggestions">
#        <ul id="searchresults" style="list-style: none;">
#         <li class="item-master" data-ng-repeat="book in books">
#          <div class="capa">
#           <a data-ng-href="/livro/{{book.livro_id}}ED{{book.id}}" ng-cloack="" rel="nofollow" title="{{book.nome_portugues}}">
#            <img alt="" data-ng-src="{{book.img_url}}" ng-cloack=""/>
#           </a>
#          </div>
#          <div class="search-item-links">
#           <div class="search-item-links-base">
#            <strong>
#             <a class="l13ab" data-ng-href="/livro/{{book.livro_id}}ED{{book.id}}" ng-cloack="" rel="nofollow">
#              <book-name-format max="50" name="book.nome_portugues" serie="book.serie" volume="book.volume">
#              </book-name-format>
#             </a>
#            </strong>
#            <div class="busca-subtitulo">
#             <span data-ng-bind="book.subtitulo_portugues| limitTo:60" ng-cloack="">
#             </span>
#            </div>
#            <div class="busca-autor">
#             <span data-ng-bind="book.autor| limitTo:60" ng-cloack="">
#             </span>
#            </div>
#           </div>
#           <div class="mini">
#            <img alt="espanha" class="bandeira" data-ng-if="book.idioma === 'es'" src="//static-sp.skoob.com.br/flag/es.gif" title="espanha"/>
#            <img alt="ingles" class="bandeira" data-ng-if="book.idioma === 'us'" src="//static-sp.skoob.com.br/flag/us.gif" title="ingles"/>
#            <img alt="alemanha" class="bandeira" data-ng-if="book.idioma === 'al'" src="//static-sp.skoob.com.br/flag/ge.gif" title="alemanha"/>
#            <img alt="russia" class="bandeira" data-ng-if="book.idioma === 'rs'" src="//static-sp.skoob.com.br/flag/ru.gif" title="russia"/>
#            <img alt="japao" class="bandeira" data-ng-if="book.idioma === 'jp'" src="//static-sp.skoob.com.br/flag/jp.gif" title="japao"/>
#            <img alt="holanda" class="bandeira" data-ng-if="book.idioma === 'hl'" src="//static-sp.skoob.com.br/flag/nl.gif" title="holanda"/>
#            <img alt="franca" class="bandeira" data-ng-if="book.idioma === 'fr'" src="//static-sp.skoob.com.br/flag/fr.gif" title="franca"/>
#            <img alt="portugal" class="bandeira" data-ng-if="book.idioma === 'pt'" src="//static-sp.skoob.com.br/flag/pt.gif" title="portugual"/>
#            <img alt="italia" class="bandeira" data-ng-if="book.idioma === 'it'" src="//static-sp.skoob.com.br/flag/it.gif" title="italia"/>
#            <img alt="esperanto" class="bandeira" data-ng-if="book.idioma === 'ep'" src="//static-sp.skoob.com.br/flag/ep.gif" title="esperanto"/>
#            <img alt="brasil" class="bandeira" data-ng-if="book.idioma === 'br'" src="//static-sp.skoob.com.br/flag/br.gif" title="brasil"/>
#            <a class="l11" data-ng-href="/editora/{{book.editora_id}}-{{book.editora}}" data-ng-if="book.editora_id &gt; 0" ng-cloack="">
#             {{book.editora}}
#            </a>
#            <span data-ng-if="book.editora_id === 0">
#             {{book.editora}}
#            </span>
#            <span data-ng-if="book.qt_edicoes &lt;= 1">
#             | edições:
#             <span data-ng-bind="book.qt_edicoes">
#             </span>
#            </span>
#            <span data-ng-if="book.qt_edicoes &gt; 1">
#             | edições:
#             <a class="l11" data-ng-bind="book.qt_edicoes" data-ng-href="/livro/edicoes/{{book.livro_id}}" ng-cloack="">
#             </a>
#            </span>
#            <span>
#             | leitores:
#             <span data-ng-bind="book.qt_estantes | numberDecimal">
#             </span>
#            </span>
#           </div>
#          </div>
#          <br clear="all"/>
#         </li>
#         <li data-ng-cloak="">
#          <form action="/livro/lista" method="post">
#           <input name="data[Busca][tag]" ng-cloack="" type="hidden" value='"{{busca}}"'/>
#           <input name="data[Busca][tipo]" type="hidden" value="livro"/>
#           <button type="submit">
#            Ver todos os (
#            <span data-ng-bind="search_total | numberDecimal" ng-cloack="">
#            </span>
#            ) resultados
#           </button>
#          </form>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div id="topo-menu-dinamico">
#       <div id="topo-menu-login">
#        <a class="l13" href="/login/" rel="nofollow" title="Acesse">
#         Entrar
#        </a>
#       </div>
#       <ul class="nav nav-pills" id="topo-menu-explorar" style="float:left; margin-right: 0px; border:0px solid red; height: 36px; padding: 0px; margin: 0px;">
#        <li class="dropdown" style="margin-top: -2px;">
#         <a class="dropdown-toggle--" data-toggle="dropdown" href="#" style="border-bottom:4px solid #fff; margin-top:5px;">
#          Explorar
#          <b class="caret">
#          </b>
#         </a>
#         <ul aria-labelledby="dLabel" class="dropdown-menu" id="topo-menu-explorar-hover" role="menu" style="margin-top: 5px;  border:0px solid black;">
#          <li>
#           <a href="/livro/lista/" title="Livros">
#            Livros
#           </a>
#          </li>
#          <li>
#           <a href="/autor/recentes/" title="Autores">
#            Autores
#           </a>
#          </li>
#          <li>
#           <a href="/editoras/" title="Editoras">
#            Editoras
#           </a>
#          </li>
#          <li>
#           <a href="/usuario/lista" title="Leitores">
#            Leitores
#           </a>
#          </li>
#          <li>
#           <a href="/grupo/atualizados/" rel="nofollow" title="Grupos">
#            Grupos
#           </a>
#          </li>
#          <li>
#           <a href="/plus/" rel="nofollow" title="Trocas">
#            Plus - Trocas
#           </a>
#          </li>
#          <li>
#           <a href="/cortesia/" title="Cortesias">
#            Cortesias
#           </a>
#          </li>
#          <li>
#           <a href="/livro/lancamentos/" title="Lançamentos">
#            Lançamentos
#           </a>
#          </li>
#          <li>
#           <a href="/livro/top_mais/lidos/" title="Top Mais">
#            Top Mais
#           </a>
#          </li>
#          <li>
#           <a href="/booktubers/" title="Booktubers">
#            Booktubers
#           </a>
#          </li>
#          <li>
#           <a href="/meta/ano/2023/" title="Meta de Leitura 2023">
#            Meta de Leitura 2023
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#      </div>
#      <br clear="all"/>
#     </div>
#    </div>
#    <div style="margin-top:60px;">
#     <style>
#      #banner-livro-home-container {
#         background-color: #f1f1f1;
#         padding: 8px 0px;
#         border:0px solid #e4e4e4;
#         /*text-align: center; */
#         margin-top: -10px;
#         margin-bottom: 20px;
#         /*min-height:90px;*/
#         height: auto;
#         -webkit-transition: width 2s, height 2s; /* For Safari 3.1 to 6.0 */
#         transition: width 2s, height 2s;
#         display: flex;
#         flex-direction: row; justify-content: center; align-content: center; align-items: center;
#     }
#     </style>
#     <div id="banner-livro-home-container">
#      <style>
#       .banner-livro-home-container {
#                 background-color: #f0f0f0;
#                 /* padding: 8px 0px; */
#                 border:0px solid #e4e4e4;
#                 /*text-align: center; */
#                 /* margin-top: -10px; */
#                 /* margin-bottom: 20px; */
#                 /*min-height:90px;*/
#                 height: auto;
#                 -webkit-transition: width 2s, height 2s; /* For Safari 3.1 to 6.0 */
#                 transition: width 2s, height 2s;
#                 display: flex;
#                 flex-direction: row; justify-content: center; align-content: center; align-items: center;
#         }
#      </style>
#      <div class="banner-livro-home-container">
#       <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js">
#       </script>
#       <script>
#        var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#       </script>
#       <script>
#        googletag.cmd.push(function() {
#     googletag.defineSlot('/101690757/SK-TOP-ADX-728X90', [728, 90], 'div-gpt-ad-1543064541532-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.pubads().collapseEmptyDivs();
#     googletag.enableServices();
#   });
#       </script>
#       <div id="div-gpt-ad-1543064541532-0" style="height:90px; width:728px;">
#        <script>
#         googletag.cmd.push(function() { googletag.display('div-gpt-ad-1543064541532-0'); });
#        </script>
#       </div>
#      </div>
#     </div>
#     <div style="width:970px;margin:auto;">
#     </div>
#     <div class="container-inf" id="container-full">
#      <div data-ng-controller="mainCtrl as main" id="corpo">
#       <style>
#        #menu_lancamentos {
#                     list-style: none;
#                     margin: 0px; padding: 0px; margin-top: 15px;
#           }
#           #menu_lancamentos li {
#                     border:1px dotted #e4e4e4; margin-bottom: 5px; padding-bottom: 5px;border-width: 0px 0px 1px 0px; color: #0064A6; text-decoration: none;
#           }
#           #menu_lancamentos li a:visited, li a:hover, li a:link {
#                     color: #0064A6; text-decoration: none;
#           }
#           #menu_lancamentos li a:hover {
#                     color:#F60;
#           }
#       </style>
#       <h1 class="t1" style="margin:0px; padding: 0px; border: none; margin-top: 15px;">
#        Top Mais Lidos
#       </h1>
#       <div style="border:#ccc 1px solid; padding: 5px 0px 15px 0px; font-size: 14px; margin-bottom: 15px; border-width: 0px 0px 1px 0px;">
#        Abaixo a lista dos livros mais marcados como "lidos" no SKOOB.
#       </div>
#       <div id="troca">
#        <div style="border:0px solid red; float:left; width: 125px;">
#         <h3 style="font-size:15px; padding:0px; margin:0px; margin-top: 10px;">
#          Top Mais
#         </h3>
#         <ul id="menu_lancamentos">
#          <li>
#           <a href="/livro/top_mais/lidos/">
#            Mais Lidos
#           </a>
#          </li>
#          <li>
#           <a href="/livro/top_mais/lendo/">
#            Mais Lendo
#           </a>
#          </li>
#          <li>
#           <a href="/livro/top_mais/queroler/">
#            Mais Quero ler
#           </a>
#          </li>
#          <li>
#           <a href="/livro/top_mais/abandonados/">
#            Mais Abandonados
#           </a>
#          </li>
#          <li>
#           <a href="/livro/top_mais/desejados/">
#            Mais Desejados
#           </a>
#          </li>
#          <li>
#           <a href="/livro/top_mais/favoritos/">
#            Mais Favoritos
#           </a>
#          </li>
#          <li>
#           <a href="/livro/top_mais/trocados/">
#            Mais Trocados
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div style="border:blue 0px solid; width:829px; float:right;">
#         <div style="text-align: center; background-color: #f1f1f1; margin: 0px; vertical-align: middle; margin-bottom: 15px;">
#          <script type="text/javascript">
#           googletag.cmd.push(function () {
#                   googletag.defineSlot('/101690757/BOOK-HOME', [[728, 90], [735, 100]], 'div-gpt-ad-1432318237463-0').addService(googletag.pubads());
#                   googletag.pubads().enableSingleRequest();
#                   googletag.enableServices();
#               });
#          </script>
#          <div id="div-gpt-ad-1432318237463-0" style=" min-height: 90px; width:728px; margin: 0 auto;">
#           <script type="text/javascript">
#            googletag.cmd.push(function () {
#                       googletag.display('div-gpt-ad-1432318237463-0');
#                   });
#           </script>
#          </div>
#         </div>
#         <div id="estante" style="width:804px;">
#          <div id="paginacao_loading" style=" height:18px; border:red  0px solid;  background-color:#fff; font-size:12px; color:#000; width:240px; padding: 2px 2px 2px 10px;  display: none; position: absolute;">
#          </div>
#          <div class="paginacao_lista_busca_down">
#           <div class="contador">
#            <b style="font-size:15px; color:#666666;">
#             106 encontrados
#            </b>
#            | exibindo 1 a 106
#           </div>
#           <div class="proximo">
#           </div>
#           <div class="numeros">
#           </div>
#           <div class="anterior">
#           </div>
#           <br clear="all"/>
#          </div>
#          <div style="border:red 0px solid; margin:10px 0px;">
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; text-align:center; position:relative;">
#            <a href="/o-pequeno-principe-693ed56597.html" target="_blank">
#             <img src="https://img.skoob.com.br/4aDk6RTtOfFDpkJaci8jzjQhoCE=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/693/O_PEQUENO_PRINCIPE_1441584936693SK1441584936B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              1
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             733.806
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(56597)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; text-align:center; position:relative;">
#            <a href="/harry-potter-e-a-pedra-filosofal-108ed323291.html" target="_blank">
#             <img src="https://img.skoob.com.br/SN8zwwKKx45bMqoJVJn4InJaWJ4=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/108/HARRY_POTTER_E_A_PEDRA_FILOSOFAL_1389761588B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              2
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             699.281
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(323291)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; text-align:center; position:relative;">
#            <a href="/a-culpa-e-das-estrelas-247555ed277187.html" target="_blank">
#             <img src="https://img.skoob.com.br/OvcfEQNINYmb4zuiEqUim8Q4pUs=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/247555/A_CULPA_E_DAS_ESTRELAS_1447651029247555SK1447651029B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              3
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             594.040
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(277187)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; text-align:center; position:relative;">
#            <a href="/harry-potter-e-a-camara-secreta-357ed476.html" target="_blank">
#             <img src="https://img.skoob.com.br/0G4f2RPCmeO9A7a75JD5yHMygQ8=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/357/HARRY_POTTER_E_A_CAMARA_SECRETA_1343592468B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              4
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             592.731
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(476)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; text-align:center; position:relative;">
#            <a href="/harry-potter-e-o-prisioneiro-de-azkaban-358ed21894.html" target="_blank">
#             <img src="https://img.skoob.com.br/OtqlPK38BEAqwTTmBks5puo_GIw=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/358/HARRY_POTTER_E_O_PRISIONEIRO_D_1451338416358SK1451338416B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              5
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             546.084
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(21894)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; text-align:center; position:relative;">
#            <a href="/harry-potter-e-o-calice-de-fogo-355ed469.html" target="_blank">
#             <img src="https://img.skoob.com.br/WNVkoHJGvDn3zTNHiCYKSgxZNfI=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/355/HARRY_POTTER_E_O_CALICE_DE_FOGO_1343592881B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              6
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             501.669
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(469)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; margin-right:0px; text-align:center; position:relative;">
#            <a href="/harry-potter-e-a-ordem-da-fenix-359ed479.html" target="_blank">
#             <img src="https://img.skoob.com.br/30kpqMQCam6vPLHdFidCSK8jtxc=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/359/HARRY_POTTER_E_A_ORDEM_DA_FENIX_1343593292B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              7
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             461.864
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(479)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; text-align:center; position:relative;">
#            <a href="/harry-potter-e-o-enigma-do-principe-562ed730.html" target="_blank">
#             <img src="https://img.skoob.com.br/9DvP0ZxwIaHEcqFz03ymyfs71QY=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/562/HARRY_POTTER_E_O_ENIGMA_DO_PRI_1424051110562SK1424051110B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              8
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             453.153
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(730)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; text-align:center; position:relative;">
#            <a href="/o-ladrao-de-raios-736ed116259.html" target="_blank">
#             <img src="https://img.skoob.com.br/B_ngYTToLtZRZxC413oKOP5sf70=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/736/O_LADRAO_DE_RAIOS_1364235342B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              9
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             449.761
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(116259)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; text-align:center; position:relative;">
#            <a href="/harry-potter-e-as-reliquias-da-morte-1200ed1643.html" target="_blank">
#             <img src="https://img.skoob.com.br/aFuHnC6eOR8wXVPD8Sc8K9R5Xcc=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/1200/HARRY_POTTER_E_AS_RELIQUIAS_DA_14475522561200SK1447552256B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              10
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             437.876
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(1643)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; text-align:center; position:relative;">
#            <a href="/crepusculo-49ed356977.html" target="_blank">
#             <img src="https://img.skoob.com.br/4sPcaoVKGQ-iFYpipW_9BW8jAbE=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/49/CREPUSCULO_1394253998B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              11
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             415.049
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(356977)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; text-align:center; position:relative;">
#            <a href="/a-menina-que-roubava-livros-7ed268782.html" target="_blank">
#             <img src="https://img.skoob.com.br/3JiPgohZ52qDUQACyL7LDQVr5eE=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/7/A_MENINA_QUE_ROUBAVA_LIVROS_14476507387SK1447650738B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              12
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             414.820
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(268782)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; text-align:center; position:relative;">
#            <a href="/a-selecao-248922ed278717.html" target="_blank">
#             <img src="https://img.skoob.com.br/7ECRzlqGqxLjBcfbK2qChA22cM0=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/248922/A_SELECAO_1371187729B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              13
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             392.698
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(278717)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; margin-right:0px; text-align:center; position:relative;">
#            <a href="/lua-nova-48ed103570.html" target="_blank">
#             <img src="https://img.skoob.com.br/sXQFRqj1Qb665kcoW5UnUE7gGMg=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/48/LUA_NOVA_143809158248SK1438091582B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              14
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             341.816
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(103570)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; text-align:center; position:relative;">
#            <a href="/o-mar-de-monstros-25835ed33990.html" target="_blank">
#             <img src="https://img.skoob.com.br/hWlm9HTuKh6DN5uBhO1OY2UVMig=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/25835/O_MAR_DE_MONSTROS_1374856845B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              15
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             340.727
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(33990)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; text-align:center; position:relative;">
#            <a href="/a-cabana-57ed77.html" target="_blank">
#             <img src="https://img.skoob.com.br/_lN7pYldufcH526_nh69DZSC1nc=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/57/A_CABANA_1398878150B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              16
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             333.838
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(77)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; text-align:center; position:relative;">
#            <a href="/o-menino-do-pijama-listrado-101ed408901.html" target="_blank">
#             <img src="https://img.skoob.com.br/Z9i7lHby98V47RR7C9jFSBhBJU4=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/101/O_MENINO_DO_PIJAMA_LISTRADO_1388769075B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              17
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             332.381
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(408901)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; text-align:center; position:relative;">
#            <a href="/eclipse-567ed45999.html" target="_blank">
#             <img src="https://img.skoob.com.br/JowaPxZw_n6lmJvAsX8PFkWbjio=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/567/ECLIPSE__1394254584B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              18
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             329.573
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(45999)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; text-align:center; position:relative;">
#            <a href="/a-elite-278916ed312764.html" target="_blank">
#             <img src="https://img.skoob.com.br/zcbVi_wtJur7ZV1108CwCUuGPM8=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/278916/A_ELITE_1363909146B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              19
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             327.143
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(312764)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; text-align:center; position:relative;">
#            <a href="/jogos-vorazes-106468ed118175.html" target="_blank">
#             <img src="https://img.skoob.com.br/5oZjc-avu3tQx9DQqZGlIg42q3A=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/106468/JOGOS_VORAZES_1447803914106468SK1447803914B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              20
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             325.554
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(118175)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; margin-right:0px; text-align:center; position:relative;">
#            <a href="/amanhecer-18562ed19919.html" target="_blank">
#             <img src="https://img.skoob.com.br/-pKwI8w0R78m8Vb1fPz1HbBWisg=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/18562/AMANHECER_1394254953B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              21
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             321.894
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(19919)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="livro-capa-mini" style="margin:0px 15px 10px 0px; padding:0px;height:200px;width:102px; border:0px solid blue; text-aling:center; float:left; position:relative; margin-bottom:5px; text-align:center; position:relative;">
#            <a href="/o-diario-de-anne-frank-17724ed19114.html" target="_blank">
#             <img src="https://img.skoob.com.br/LdPqWopWzmJa7E2grgmnskybaio=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/17724/O_DIARIO_DE_ANNE_FRANK_147225333917724SK1472253339B.jpg" style="border:1px solid #e4e4e4;"/>
#            </a>
#            <div style="border:0px solid red; position:absolute; top:0px; left:0px; width:22px; height:22px; padding:8px 5px 2px 5px;;background-color:#009900;">
#             <span style="font-size:13px; font-weight:bold; color:#fff;">
#              22
#             </span>
#            </div>
# ...
#              106
#             </span>
#            </div>
#            <div style="border:0px solid red; margin-top:0px;">
#             100.542
#            </div>
#            <div style="border:0px solid red; text-align:right; margin:5px;">
#             <div class="sidebar-buy" data-ng-controller="ofertaCtrl" style="font-size:13px; border:none; padding: 0px; margin: 0px; margin-top: 5px;">
#              <div style="text-align: center;">
#               <i class="icon-cart" style="font-size: 13px; color:#556677;">
#               </i>
#               <a data-ng-click="open(470)" href="javascript:{}">
#                ver ofertas
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#           <script id="modalOfertas.html" type="text/ng-template">
#            <div class="modal-header">
#       <h3 class="modal-title" style="font-size:15px; color:#333;">Ofertas encontradas</h3>
#       </div>
#       <div class="modal-body" style="border:0px solid blue; padding-top:2px;">
#
#       <div data-ng-if="modal_empty == true" style='margin:30px 0px; color:#333; font-size:22px; font-weight:bold;'>Nenhuma oferta disponível no momento.</div>
#
#                    <img data-ng-if="modal_loading"  src="//static-sp.skoob.com.br/css/v3/img/load-padrao-big.gif" data-ng-cloak>
#                     <ul style="border:0px solid red; list-style-type:none; margin-bottom:15px;">
#                     <li data-ng-repeat="item in items">
#
#                     <div style="border:1px solid #f1f1f1; border-width:0px 0px 1px 0px; padding:4px; margin:5px 0px; height: 30px;">
#
#                     <img data-ng-src="//static-sp.skoob.com.br/css/livraria-{{ item.lojas_anuncios_id }}.jpg" style='border:0px solid #ccc; float:left; width:100px;' width="100" />
#                                         <div style='text-align:right;width:120px; float:right; border:0px solid red; margin-top:5px;'><a href="/compra/loja/{{ item.lojas_anuncios_id }}/?redirect={{ item.url }}" target="_blank" class="btn btn-primary" style="height:20px; padding:3px 20px;">Ir à Loja</a></div>
#                                         <div style='text-align:left; margin-top:5px;width:120px; float:right; border:0px solid green; height:30px;'><strong>R$ {{ item.preco }}<strong></div>
#                     <br clear="all">
#                     </div>
#                     </li>
#                     </ul>
#
#             <div style="font-size:11px; text-align:left; font-weight:normal;">
#                   <b>Importante: </b> É possível haver diferença entre o valor anunciado aqui e o site da loja. Quando acontecer, prevalecerá sempre o preço no site da loja.
#             </div>
#       </div>
#           </script>
#           <br clear="all"/>
#          </div>
#          <div class="paginacao_lista_busca">
#           <div class="contador">
#            <b style="font-size:15px; color:#666666;">
#             106 encontrados
#            </b>
#            | exibindo 1 a 106
#           </div>
#           <div class="proximo">
#           </div>
#           <div class="numeros">
#           </div>
#           <div class="anterior">
#           </div>
#           <br clear="all"/>
#          </div>
#         </div>
#        </div>
#        <br clear="all"/>
#       </div>
#      </div>
#     </div>
#     <footer class="footer footer-skoob" style="margin-top: 15px; border:0px solid red;">
#      <div class="footer-skoob-main">
#       <div class="footer-container">
#        <div class="footer-logo-icons-container">
#         <div class="footer-logo-info">
#          <div class="footer-logo">
#           <img alt="" class="logo-footer" src="https://static-sp.skoob.com.br/img/v2/logo-footer.png" style="margin-bottom: 5px;margin-right: 15px; width:70px;"/>
#          </div>
#          <div class="footer-info">
#           Somos a maior rede social do Brasil criada especialmente para quem ama ler.
# Junte-se aos mais de 9 milhões de leitores e compartilhe experiências literárias.
#          </div>
#         </div>
#         <div>
#          <div class="footer-icons">
#           <a alt="Facebook - Skoob" class="footer-icons-link" href="//www.facebook.com/skoobnews" target="_blank" title="Facebook - Skoob">
#            <i class="fa fa-facebook-square">
#            </i>
#           </a>
#           <a alt="Youtube - Skoob" class="footer-icons-link" href="//www.youtube.com/user/skoobnews" target="_blank" title="Youtube - Skoob">
#            <i class="fa fa-youtube-square">
#            </i>
#           </a>
#           <a alt="Twitter - Skoob" class="footer-icons-link" href="//twitter.com/skoobnews" rel="nofollow" target="_blank" title="Twitter - Skoob">
#            <i class="fa fa-twitter-square">
#            </i>
#           </a>
#           <a alt="Instagram - Skoob" class="footer-icons-link" href="//instagram.com/skoobnews" rel="nofollow" target="_blank" title="Instagram - Skoob">
#            <i class="fa fa-instagram">
#            </i>
#           </a>
#          </div>
#          <div class="footer-icons-container">
#           <div class="footer-app-stores">
#            <h5 style="font-weight:600; margin:10px 0px !important; font-size: 14px;">
#             Baixe nosso app
#            </h5>
#            <div class="apps">
#             <a href="https://itunes.apple.com/br/app/skoob/id904670263?l=pt&amp;ls=1&amp;mt=8">
#              <img alt="Baixe para iPhone" class="mb-2" src="https://static-sp.skoob.com.br/img/mkt/2015-SET/app-store.jpg" style="height:33px;"/>
#             </a>
#             <a href="https://play.google.com/store/apps/details?id=com.gaudium.skoob&amp;hl=pt_BR">
#              <img alt="Baixe para Android" class="mb-2" src="https://static-sp.skoob.com.br/img/mkt/2015-SET/google-play.jpg" style="height:33px;"/>
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="footer-links-icons-container">
#         <div class="footer-links-container">
#          <ul class="footer-ul">
#           <li class="footer-li">
#            <a class="footer-li-link" href="/ajuda/faq">
#             FAQ
#            </a>
#           </li>
#           <li class="footer-li">
#            <a class="footer-li-link" href="/inicio/quem_somos">
#             Quem Somos
#            </a>
#           </li>
#           <li class="footer-li">
#            <a class="footer-li-link" href="//blog.skoob.com.br/">
#             Blog
#            </a>
#           </li>
#           <li class="footer-li">
#            <a class="footer-li-link" href="/acervo/adicionar/">
#             Cadastro de livros
#            </a>
#           </li>
#           <li class="footer-li">
#            <a class="footer-li-link" href="/autor/checar/">
#             Cadastro de autores
#            </a>
#           </li>
#           <li class="footer-li">
#            <a class="footer-li-link" href="/downloads/">
#             Downloads
#            </a>
#           </li>
#           <li class="footer-li">
#            <a class="footer-li-link" href="/ajuda/faq">
#             Fale Conosco
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="footer-last-container">
#       <div class="footer-last-links-container">
#        <ul class="footer-last-ul">
#         <li style="list-style: none;display: inline;padding: 0 12px;border-right: 1px solid #fff;font-size: 14px;margin: 0;">
#          <a href="/livro/lista/" style="color:#fff;" title="Livros">
#           Livros
#          </a>
#         </li>
#         <li style="list-style: none;display: inline;padding: 0 12px;border-right: 1px solid #fff;font-size: 14px;margin: 0;">
#          <a href="/autor/recentes/" style="color:#fff;" title="Autores">
#           Autores
#          </a>
#         </li>
#         <li style="list-style: none;display: inline;padding: 0 12px;border-right: 1px solid #fff;font-size: 14px;margin: 0;">
#          <a href="/editoras/" style="color:#fff;" title="Editoras">
#           Editoras
#          </a>
#         </li>
#         <li style="list-style: none;display: inline;padding: 0 12px;border-right: 1px solid #fff;font-size: 14px;margin: 0;">
#          <a href="/usuario/lista" style="color:#fff;" title="Leitores">
#           Leitores
#          </a>
#         </li>
#         <li style="list-style: none;display: inline;padding: 0 12px;border-right: 1px solid #fff;font-size: 14px;margin: 0;">
#          <a href="/cortesia/" style="color:#fff;" title="Cortesias">
#           Cortesias
#          </a>
#         </li>
#         <li style="list-style: none;display: inline;padding: 0 12px;border-right: 1px solid #fff;font-size: 14px;margin: 0;">
#          <a href="/livro/lancamentos/" style="color:#fff;" title="Lançamentos">
#           Lançamentos
#          </a>
#         </li>
#         <li style="list-style: none;display: inline;padding: 0 12px;border-right: 1px solid #fff;font-size: 14px;margin: 0;">
#          <a href="/meta/ano/2023/" style="color:#fff;" title="Meta de Leitura">
#           Meta de Leitura 2023
#          </a>
#         </li>
#         <li style="list-style: none;display: inline;padding: 0 12px;border-right: 1px solid #fff;font-size: 14px;margin: 0;">
#          <a href="https://skoob-sp.s3-sa-east-1.amazonaws.com/app-files/termo_de_uso_skoob.pdf" style="color:#fff;" target="_blank" title="Termo de Uso">
#           Termo de Uso
#          </a>
#         </li>
#         <li style="list-style: none;display: inline;padding: 0 12px;border-right: 0px solid #fff;font-size: 14px;margin: 0;">
#          <a href="https://www.skoob.com.br/ajuda/privacidade" style="color:#fff;" target="_blank" title="Privacidade">
#           Privacidade
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </footer>
#     <style>
#      .container-lgpd {
#         border-radius: 10px;
#         padding: 20px;
#         position: fixed;
#         bottom: 40px;
#         width: 250px;
#         display: flex;
#         flex-direction: column;
#         right: 50px;
#         border: #3189C8 solid 6px;
#         background-color: #fbf3bc;
#
#     }
#
#     .content-text-lgpd {
#         font-size: 15px;
#         color: #333;
#         margin-bottom: 15px;
#     }
#
#     .link-lgpd:link, .link-lgpd:hover, .link-lgpd:visited  {
#         font-size: 15px;
#         font-weight: normal;
#         color: #0069D9;
#     }
#     </style>
#     <div class="container-lgpd">
#      <span class="content-text-lgpd">
#       Utilizamos cookies e tecnologia para aprimorar sua experiência de navegação de acordo com a
#       <a class="link-lgpd" href="https://www.skoob.com.br/ajuda/privacidade" target="_blank">
#        Política de Privacidade.
#       </a>
#      </span>
#      <a class="btn btn-success" href="?privacy-agree=true">
#       ACEITAR
#      </a>
#     </div>
#    </div>
#   </div>
#  </body>
#  <script src="//www.google.com/jsapi" type="text/javascript">
#  </script>
#  <script type="text/javascript">
#   _atrk_opts = { atrk_acct:"wIE9i1acVE00MP", domain:"skoob.com.br",dynamic: true};
# (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://www.skoob.com.br/js/alexa/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
#  </script>
#  <noscript>
#   <img alt="" height="1" src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=wIE9i1acVE00MP" style="display:none" width="1"/>
#  </noscript>
#  <script type="text/javascript">
#   var gaJsHost = (("https:" == document.location.protocol) ? "//ssl." : "//www.");
#                 document.write(unescape("%3Cscript src='" + gaJsHost + "google-analytics.com/ga.js' type='text/javascript'%3E%3C/script%3E"));
#  </script>
#  <script type="text/javascript">
#   var pageTracker = _gat._getTracker("UA-6452051-1");
#         pageTracker._trackPageview();
#  </script>
#  <script async="" src="//rtgpix.com/resources/scripts/src/pixel_skoob.js" type="text/javascript">
#  </script>
#  <script type="text/javascript">
#   window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(13),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,-1!==o.indexOf("dev")&&(s.dev=!0),-1!==o.indexOf("nr_dev")&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,o){try{d?d-=1:i("err",[o||new UncaughtException(t,e,n)])}catch(s){try{i("ierr",[s,(new Date).getTime(),!0])}catch(c){}}return"function"==typeof f?f.apply(this,a(arguments)):!1}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t){i("err",[t,(new Date).getTime()])}var i=t("handle"),a=t(14),s=t("ee"),c=t("loader"),f=window.onerror,u=!1,d=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(l){"stack"in l&&(t(7),t(6),"addEventListener"in window&&t(4),c.xhrWrappable&&t(8),u=!0)}s.on("fn-start",function(t,e,n){u&&(d+=1)}),s.on("fn-err",function(t,e,n){u&&(this.thrown=!0,o(n))}),s.on("fn-end",function(){u&&!this.thrown&&d>0&&(d-=1)}),s.on("internal-error",function(t){i("ierr",[t,(new Date).getTime(),!0])})},{}],3:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(7),s=t(6);t("loader").features.stn=!0,t(5);var c=NREUM.o.EV;o.on("fn-start",function(t,e){var n=t[0];n instanceof c&&(this.bstStart=Date.now())}),o.on("fn-end",function(t,e){var n=t[0];n instanceof c&&i("bst",[n,e,this.bstStart,Date.now()])}),a.on("fn-start",function(t,e,n){this.bstStart=Date.now(),this.bstType=n}),a.on("fn-end",function(t,e){i("bstTimer",[e,this.bstStart,Date.now(),this.bstType])}),s.on("fn-start",function(){this.bstStart=Date.now()}),s.on("fn-end",function(t,e){i("bstTimer",[e,this.bstStart,Date.now(),"requestAnimationFrame"])}),o.on("pushState-start",function(t){this.time=Date.now(),this.startPath=location.pathname+location.hash}),o.on("pushState-end",function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),"addEventListener"in window.performance&&(window.performance.clearResourceTimings?window.performance.addEventListener("resourcetimingbufferfull",function(t){i("bstResource",[window.performance.getEntriesByType("resource")]),window.performance.clearResourceTimings()},!1):window.performance.addEventListener("webkitresourcetimingbufferfull",function(t){i("bstResource",[window.performance.getEntriesByType("resource")]),window.performance.webkitClearResourceTimings()},!1)),document.addEventListener("scroll",r,!1),document.addEventListener("keypress",r,!1),document.addEventListener("click",r,!1)}},{}],4:[function(t,e,n){function r(t){for(var e=t;e&&!e.hasOwnProperty(u);)e=Object.getPrototypeOf(e);e&&o(e)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,e){return t[1]}var a=t("ee").get("events"),s=t(15)(a),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";e.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,e){if(t[1]){var n=t[1];if("function"==typeof n){var r=c(n,"nr@wrapped",function(){return s(n,"fn-",null,n.name||"anonymous")});this.wrapped=t[1]=r}else"function"==typeof n.handleEvent&&s.inPlace(n,["handleEvent"],"fn-")}}),a.on(d+"-start",function(t){var e=this.wrapped;e&&(t[1]=e)})},{}],5:[function(t,e,n){var r=t("ee").get("history"),o=t(15)(r);e.exports=r,o.inPlace( ...
# ;NREUM.info={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",licenseKey:"9e53d555d8",applicationID:"17961617",sa:1}
#  </script>
# </html>

# %%
soup_mais_lidos.find_all(['a'], attrs = {"target" : "_blank"})[0]
# Out:
# <a href="/o-pequeno-principe-693ed56597.html" target="_blank"><img src="https://img.skoob.com.br/4aDk6RTtOfFDpkJaci8jzjQhoCE=/100x155/center/top/smart/filters:format(jpeg)/https://skoob.s3.amazonaws.com/livros/693/O_PEQUENO_PRINCIPE_1441584936693SK1441584936B.jpg" style="border:1px solid #e4e4e4;"/></a>

# %%
mais_lidos = [soup_mais_lidos.find_all(['a'], attrs = {"target" : "_blank"})[i].get('href') for i in range(106)]

# %%
mais_lidos
# Out:
# ['/o-pequeno-principe-693ed56597.html',
#  '/harry-potter-e-a-pedra-filosofal-108ed323291.html',
#  '/a-culpa-e-das-estrelas-247555ed277187.html',
#  '/harry-potter-e-a-camara-secreta-357ed476.html',
#  '/harry-potter-e-o-prisioneiro-de-azkaban-358ed21894.html',
#  '/harry-potter-e-o-calice-de-fogo-355ed469.html',
#  '/harry-potter-e-a-ordem-da-fenix-359ed479.html',
#  '/harry-potter-e-o-enigma-do-principe-562ed730.html',
#  '/o-ladrao-de-raios-736ed116259.html',
#  '/harry-potter-e-as-reliquias-da-morte-1200ed1643.html',
#  '/crepusculo-49ed356977.html',
#  '/a-menina-que-roubava-livros-7ed268782.html',
#  '/a-selecao-248922ed278717.html',
#  '/o-mar-de-monstros-25835ed33990.html',
#  '/lua-nova-48ed103570.html',
#  '/a-elite-278916ed312764.html',
#  '/o-menino-do-pijama-listrado-101ed408901.html',
#  '/a-cabana-57ed77.html',
#  '/eclipse-567ed45999.html',
#  '/jogos-vorazes-106468ed118175.html',
#  '/o-diario-de-anne-frank-17724ed19114.html',
#  '/amanhecer-18562ed19919.html',
#  '/a-escolha-342008ed383667.html',
#  '/o-codigo-da-vinci-248ed347.html',
#  '/a-maldicao-do-tita-43647ed47840.html',
#  '/a-batalha-do-labirinto-61651ed70047.html',
#  '/a-revolucao-dos-bichos-3074ed3967.html',
#  '/dom-casmurro-180ed247.html',
#  '/e-assim-que-acaba-738219ed740815.html',
#  '/em-chamas-144526ed160818.html',
#  '/o-ultimo-olimpiano-64463ed72685.html',
#  '/a-esperanca-175390ed195445.html',
#  '/quem-e-voce-alasca-141267ed157115.html',
#  '/anjos-e-demonios-348ed463.html',
#  '/querido-john-95748ed105919.html',
#  '/o-cacador-de-pipas-2ed3.html',
#  '/cinquenta-tons-de-cinza-242567ed273945.html',
#  '/extraordinario-297222ed383680.html',
#  '/as-cronicas-de-narnia-331ed195738.html',
#  '/como-eu-era-antes-de-voce-312435ed350014.html',
#  '/os-sete-maridos-de-evelyn-hugo-866308ed967690.html',
#  '/marley-e-eu-13ed26.html',
#  '/corte-de-espinhos-e-rosas-530755ed539188.html',
#  '/as-vantagens-de-ser-invisivel-2703ed3512.html',
#  '/a-rainha-vermelha-449028ed508729.html',
#  '/cidades-de-papel-330717ed370573.html',
#  '/o-heroi-perdido-111150ed123510.html',
#  '/cinquenta-tons-mais-escuros-244722ed273951.html',
#  '/a-guerra-dos-tronos-16048ed17437.html',
#  '/cidade-dos-ossos-53780ed353179.html',
#  '/a-ultima-musica-100083ed113879.html',
#  '/a-herdeira-407310ed496233.html',
#  '/fallen-111819ed126023.html',
#  '/o-cortico-975ed38519.html',
#  '/o-principe-cruel-803410ed807287.html',
#  '/corte-de-nevoa-e-furia-575922ed576913.html',
#  '/1984-941ed412608.html',
#  '/o-morro-dos-ventos-uivantes-110ed65816.html',
#  '/o-hobbit-509ed660.html',
#  '/memorias-postumas-de-bras-cubas-797ed1035.html',
#  '/amor-e-gelato-683238ed685660.html',
#  '/para-todos-os-garotos-que-ja-amei-445338ed504597.html',
#  '/capitaes-da-areia-968ed44887.html',
#  '/divergente-195226ed218109.html',
#  '/o-simbolo-perdido-47661ed52274.html',
#  '/teto-para-dois-915901ed922332.html',
#  '/vermelho-branco-e-sangue-azul-966717ed967680.html',
#  '/orgulho-e-preconceito-819ed1064.html',
#  '/os-contos-de-beedle-o-bardo-137ed184.html',
#  '/mentirosos-408566ed463616.html',
#  '/todas-as-suas-imperfeicoes-916209ed922642.html',
#  '/sussurro-104218ed115523.html',
#  '/corte-de-asas-e-ruina-719856ed706662.html',
#  '/o-mundo-de-sofia-134ed180.html',
#  '/a-coroa-535140ed544031.html',
#  '/fortaleza-digital-126ed173.html',
#  '/o-teorema-katherine-294316ed329772.html',
#  '/o-duque-e-eu-169842ed350200.html',
#  '/heartstopper-785266ed790256.html',
#  '/o-filho-de-netuno-182604ed203753.html',
#  '/o-lado-feio-do-amor-515134ed521888.html',
#  '/o-alquimista-3ed4.html',
#  '/iracema-354ed228.html',
#  '/verity-1103675ed1112450.html',
#  '/o-guia-do-mochileiro-das-galaxias-225ed320.html',
#  '/alice-no-pais-das-maravilhas-1172ed1600.html',
#  '/o-acordo-577064ed578131.html',
#  '/o-rei-perverso-1148152ed1150543.html',
#  '/a-sociedade-do-anel-13988ed3654.html',
#  '/assassinato-no-expresso-do-oriente-1043ed1385.html',
#  '/a-metamorfose-346ed279212.html',
#  '/a-furia-dos-reis-16061ed17448.html',
#  '/a-droga-da-obediencia-1135ed96498.html',
#  '/trono-de-vidro-328079ed367519.html',
#  '/o-despertar-30568ed33286.html',
#  '/vidas-secas-770ed246726.html',
#  '/insurgente-256843ed287582.html',
#  '/a-hospedeira-1151ed99229.html',
#  '/o-monge-e-o-executivo-18ed32.html',
#  '/a-marca-de-atena-199559ed222906.html',
#  '/o-visconde-que-me-amava-330710ed370563.html',
#  '/ps-ainda-amo-voce-541124ed550555.html',
#  '/cidade-das-cinzas-53782ed59232.html',
#  '/a-moreninha-529ed688.html',
#  '/e-assim-que-comeca-12134808ed12118613.html',
#  '/estilhaca-me-223094ed443737.html']

# %%
url_renata = 'https://www.skoob.com.br/estante/livros/todos/4326934/page:1'
response_renata = requests.get(url_renata)
html_renata = response_renata.content
soup_renata = BeautifulSoup(html_renata)
#renata = [soup_renata.find_all(['a'], attrs = {"target" : "_blank"})[i].get('href') for i in range(106)]

# %%
soup_renata.find_all(['head'])[0].get('prefix')
# Out:
# 'og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# books: http://ogp.me/ns/books#'

# %%
soup_renata
# Out:
# <!DOCTYPE html>
# <html xmlns="//www.w3.org/1999/xhtml">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# books: http://ogp.me/ns/books#">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/> <title>Login</title>
# <meta content="pt-br" name="language"/>
# <meta content="h_F9-djAws40JfpX_W4juzsPjd9YZ2v-s0YvOG-D388" name="google-site-verification"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="app-id=904670263" name="apple-itunes-app"/>
# <meta content="app-id=com.gaudium.skoob" name="google-play-app"/>
# <meta content="none" name="msapplication-config"/>
# <meta content="22240835" name="lomadee-verification"/>
# <script type="text/javascript">
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
# <script src="https://www.skoob.com.br/js/angularjs/base.min.js?1637270067" type="text/javascript"></script><script src="https://www.skoob.com.br/js/angularjs/main.min.js?1639030176" type="text/javascript"></script><link href="https://www.skoob.com.br/css/ver2/main.min.css?1639030170" rel="stylesheet" type="text/css"/><link href="/css/dist-final-2019/geral.min.css?1637268866" rel="stylesheet" type="text/css"/>
# </head>
# <body id="ng-app" ng-app="skoob" style="border:0px solid red;">
# <div style="display: flex; flex-direction: column; flex: 1; border: 0px solid green;">
# <div class="navbar navbar-fixed-top" id="topo" style="height:48px;">
# <div class="container" id="topoInterno" style="">
# <a href="/">
# <img alt="logo Skoob" class="logo" height="33" src="https://static-sp.skoob.com.br/img/v2/base/skoob-logo-topo.gif" title="logo Skoob" width="109"/> </a>
# <div data-ng-controller="SearchCtrl" data-ng-mouseleave="leave = true" id="tbusca">
# <form action="/livro/lista/" class="form-inline" id="topo-menu-search" method="post">
# <span class="busca-loading-container" data-ng-bind="search_total | numberDecimal" data-ng-cloak="" data-ng-show="search_total &gt; 0"></span>
# <div data-ng-cloak="" data-ng-show="search_loading" id="suggestions_loadingmessage">
# <img alt="loading" src="//static-sp.skoob.com.br/img/v2/base/load-padrao.gif"/>
# </div>
# <div class="input-append">
# <input autocomplete="off" class="form-control" data-ng-blur="searchExit()" data-ng-model="busca" id="search" name="data[Busca][tag]" placeholder="Busque por título, autor, editora, ISBN..." type="text"/>
# <span class="input-group-btn">
# <button class="btn btn-default btn-form-lupa" type="submit"><i class="fa fa-search"></i></button>
# </span>
# </div>
# </form>
# <div data-ng-cloak="" data-ng-mouseover="leave = false" data-ng-show="search_result" id="suggestions">
# <ul id="searchresults" style="list-style: none;">
# <li class="item-master" data-ng-repeat="book in books">
# <div class="capa">
# <a data-ng-href="/livro/{{book.livro_id}}ED{{book.id}}" ng-cloack="" rel="nofollow" title="{{book.nome_portugues}}"><img alt="" data-ng-src="{{book.img_url}}" ng-cloack=""/></a>
# </div>
# <div class="search-item-links">
# <div class="search-item-links-base">
# <strong>
# <a class="l13ab" data-ng-href="/livro/{{book.livro_id}}ED{{book.id}}" ng-cloack="" rel="nofollow">
# <book-name-format max="50" name="book.nome_portugues" serie="book.serie" volume="book.volume"></book-name-format>
# </a>
# </strong>
# <div class="busca-subtitulo"><span data-ng-bind="book.subtitulo_portugues| limitTo:60" ng-cloack=""></span></div>
# <div class="busca-autor"><span data-ng-bind="book.autor| limitTo:60" ng-cloack=""></span></div>
# </div>
# <div class="mini">
# <img alt="espanha" class="bandeira" data-ng-if="book.idioma === 'es'" src="//static-sp.skoob.com.br/flag/es.gif" title="espanha"/>
# <img alt="ingles" class="bandeira" data-ng-if="book.idioma === 'us'" src="//static-sp.skoob.com.br/flag/us.gif" title="ingles"/>
# <img alt="alemanha" class="bandeira" data-ng-if="book.idioma === 'al'" src="//static-sp.skoob.com.br/flag/ge.gif" title="alemanha"/>
# <img alt="russia" class="bandeira" data-ng-if="book.idioma === 'rs'" src="//static-sp.skoob.com.br/flag/ru.gif" title="russia"/>
# <img alt="japao" class="bandeira" data-ng-if="book.idioma === 'jp'" src="//static-sp.skoob.com.br/flag/jp.gif" title="japao"/>
# <img alt="holanda" class="bandeira" data-ng-if="book.idioma === 'hl'" src="//static-sp.skoob.com.br/flag/nl.gif" title="holanda"/>
# <img alt="franca" class="bandeira" data-ng-if="book.idioma === 'fr'" src="//static-sp.skoob.com.br/flag/fr.gif" title="franca"/>
# <img alt="portugal" class="bandeira" data-ng-if="book.idioma === 'pt'" src="//static-sp.skoob.com.br/flag/pt.gif" title="portugual"/>
# <img alt="italia" class="bandeira" data-ng-if="book.idioma === 'it'" src="//static-sp.skoob.com.br/flag/it.gif" title="italia"/>
# <img alt="esperanto" class="bandeira" data-ng-if="book.idioma === 'ep'" src="//static-sp.skoob.com.br/flag/ep.gif" title="esperanto"/>
# <img alt="brasil" class="bandeira" data-ng-if="book.idioma === 'br'" src="//static-sp.skoob.com.br/flag/br.gif" title="brasil"/>
# <a class="l11" data-ng-href="/editora/{{book.editora_id}}-{{book.editora}}" data-ng-if="book.editora_id &gt; 0" ng-cloack=""> {{book.editora}}</a>
# <span data-ng-if="book.editora_id === 0"> {{book.editora}}</span>
# <span data-ng-if="book.qt_edicoes &lt;= 1">| edições: <span data-ng-bind="book.qt_edicoes"></span></span>
# <span data-ng-if="book.qt_edicoes &gt; 1">| edições: <a class="l11" data-ng-bind="book.qt_edicoes" data-ng-href="/livro/edicoes/{{book.livro_id}}" ng-cloack=""></a></span>
# <span>| leitores: <span data-ng-bind="book.qt_estantes | numberDecimal"></span></span>
# </div>
# </div>
# <br clear="all"/>
# </li>
# <li data-ng-cloak="">
# <form action="/livro/lista" method="post">
# <input name="data[Busca][tag]" ng-cloack="" type="hidden" value='"{{busca}}"'/>
# <input name="data[Busca][tipo]" type="hidden" value="livro"/>
# <button type="submit">Ver todos os (<span data-ng-bind="search_total | numberDecimal" ng-cloack=""></span>) resultados</button>
# </form>
# </li>
# </ul>
# </div>
# </div>
# <div id="topo-menu-dinamico">
# <div id="topo-menu-login"><a class="l13" href="/login/" rel="nofollow" title="Acesse">Entrar</a></div> <ul class="nav nav-pills" id="topo-menu-explorar" style="float:left; margin-right: 0px; border:0px solid red; height: 36px; padding: 0px; margin: 0px;">
# <li class="dropdown" style="margin-top: -2px;">
# <a class="dropdown-toggle--" data-toggle="dropdown" href="#" style="border-bottom:4px solid #fff; margin-top:5px;">
# Explorar
# <b class="caret"></b>
# </a>
# <ul aria-labelledby="dLabel" class="dropdown-menu" id="topo-menu-explorar-hover" role="menu" style="margin-top: 5px;  border:0px solid black;">
# <li><a href="/livro/lista/" title="Livros">Livros</a></li>
# <li><a href="/autor/recentes/" title="Autores">Autores</a></li>
# <li><a href="/editoras/" title="Editoras">Editoras</a></li>
# <li><a href="/usuario/lista" title="Leitores">Leitores</a></li>
# <li><a href="/grupo/atualizados/" rel="nofollow" title="Grupos">Grupos</a></li>
# <li><a href="/plus/" rel="nofollow" title="Trocas">Plus - Trocas</a></li>
# <li><a href="/cortesia/" title="Cortesias">Cortesias</a></li>
# <li><a href="/livro/lancamentos/" title="Lançamentos">Lançamentos</a></li>
# <li><a href="/livro/top_mais/lidos/" title="Top Mais">Top Mais</a></li>
# <li><a href="/booktubers/" title="Booktubers">Booktubers</a></li>
# <li><a href="/meta/ano/2023/" title="Meta de Leitura 2023">Meta de Leitura 2023</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <br clear="all"/>
# </div>
# </div>
# <div style="margin-top:60px;"> <div style="width:950px;margin:auto;">
# </div>
# <div class="" id="container-full">
# <div data-ng-controller="mainCtrl as main" id="corpo">
# <link href="//static-sp.skoob.com.br/css/v3/bootstrap.carousel.css" rel="stylesheet"/>
# <div id="login-box" style="border:0px solid green; width: 960px;">
# <div id="login-box-col01" style="border:0px solid red;">
# <h1>Descubra um mundo de livros</h1>
# <h2>O Skoob é a maior e mais completa rede social para leitores do Brasil, o lugar perfeito para conhecer novos livros, fazer amizades e compartilhar o seu amor pela leitura.</h2>
# <br clear="all"/>
# <br clear="all"/>
# <div ng-controller="CarouselHomeCtrl">
# <div style="height: 305px">
# <carousel interval="myInterval">
# <slide active="slide.active">
# <img ng-src="https://static-sp.skoob.com.br/img/v2/login-amigos.jpg" style="margin:auto;"/>
# </slide>
# <slide>
# <img ng-src="https://static-sp.skoob.com.br/img/v2/login-estante.jpg" style="margin:auto;"/>
# </slide>
# <slide>
# <img ng-src="https://static-sp.skoob.com.br/img/v2/login-lancamentos.jpg" style="margin:auto;"/>
# </slide>
# </carousel>
# </div>
# </div>
# <br clear="all"/>
# </div>
# <div id="login-box-col02" style="padding-left: 50px;">
# <h2>Primeira vez no Skoob?</h2>
# <p class="subtitle-min">Cadastre-se, é fácil, rápido e totalmente gratuito</p>
# <br/>
# <p><a class="bt-facebook bt-login-txt" href="/login/facebook/"><img src="https://static-sp.skoob.com.br/img/v2/icon-facebook.jpg"/><span>Cadastre-se usando o Facebook</span></a></p>
# <p class="subtitle-min">*Usando o Facebook é muito mais fácil, nada será publicado sem a sua permissão. </p>
# <br/>
# <p><a class="bt-mail bt-login-txt" href="/cadastro/convite/"><img src="https://static-sp.skoob.com.br/img/v2/icon-mail.jpg"/><span>Cadastre-se via e-mail</span></a></p>
# <p class="subtitle-min">**Você receberá um convite para fazer o cadastro via Email. </p>
# <br/>
# <br/>
# <h2>Já sou um(a) Skoober</h2>
# <p class="subtitle-min">Então não precisamos falar mais nada... divirta-se. :) </p>
# <p><a class="bt-facebook bt-login-txt" href="/login/facebook/"><img src="https://static-sp.skoob.com.br/img/v2/icon-facebook.jpg"/><span>Entrar usando Facebook</span></a></p>
# <br/>
# <p>Ou entre usando seu e-mail.</p>
# <br/>
# <form action="/login/" method="post">
# Login (email cadastrado):<br/>
# <input class="input_template" id="UsuarioEmail" name="data[Usuario][email]" size="35" type="text"/><br/>
# Senha:<br/>
# <input class="input_template" id="UsuarioSenha" name="data[Usuario][senha]" size="10" type="password"/><br/>
# <input checked="" name="data[Login][automatico]" type="checkbox" value="true"/><span style="font-size:11px;"> Lembrar login (não marque essa opção quando estiver em computadores públicos).</span>
# <div style="border:0px solid red; margin:7px 0px;">
# <div class="submit"><input style="float:left; margin-right:10px; valign:middle; vertical-align:middle;" type="submit" value=" Entrar "/></div> <a class="l15" href="/login/esqueci_minha_senha">Esqueci minha senha</a><br/>
# <br clear="all"/>
# </div>
# </form>
# </div>
# <br clear="all"/>
# <br clear="all"/>
# </div>
# <style type="text/css">
#        #login-box{width:920px;margin:auto;}
#        #login-box-col01{width:500px;float:left;margin-right:30px;}
#        #login-box-col01 h1{font-size:33px !important;margin:0px;}
#        #login-box-col01 h2{font-size:17px;margin:30px 0px 0px 0px !Important;font-weight: normal;}
#        #login-box-col02{width:347px;float:left;border-left:1px solid #ccc;padding-left:30px;}
#        .carousel-caption h4{margin:-314px 0px 0px -100px !important;background:#5B8384;padding:10px !Important;width:480px;color:#fff;}
#        .carousel-caption h5{margin-left:-100px !important;bottom:-20px;background:#5B8384;padding:10px !Important;width:500px;position:absolute;color:#fff;}
#        .carousel-indicators{display:none;}
#        .bt-facebook{background:#3B589C;color:#fff;text-shadow:1px 1px 0px #304880;}
#        .bt-mail{background:#3282BC;color:#fff;text-shadow:2px 2px 0px #3278B1;}
#        .bt-login-txt{padding:5px 5px 5px 5px;font-size:15px !important;border-radius:5px;width:344px;display:block;font-weight:bold;color:#fff !Important;height:32px;}
#        .bt-login-txt:hover{-moz-box-shadow: 0px 1px 8px rgba(0,0,0,.4);box-shadow: 0px 1px 8px rgba(0,0,0,.4);}
#        .bt-login-txt img{border-right:1px solid #fff;margin-right:10px;padding-right:10px;float:left; border-width: 0 1px 0 0;}
#        .bt-login-txt span{margin-top:7px;float:left;}
#        .subtitle{font-size:14px;}
#        .subtitle-min{font-size:11px;}
#        #login-box-col02 .input_template{border:1px solid #ccc;padding:5px;width:99%; margin-top: 5px;}
#        .carousel-control{cursor:pointer !important;}
#
#
# </style>
# <script>
#        function CarouselHomeCtrl($scope) {
#               $scope.myInterval = 5000;
#        }
# </script> </div>
# </div>
# </div>
# <footer class="footer footer-skoob" style="margin-top: 15px; border:0px solid red;">
# <div class="footer-skoob-main">
# <div class="footer-container">
# <div class="footer-logo-icons-container">
# <div class="footer-logo-info">
# <div class="footer-logo">
# <img alt="" class="logo-footer" src="https://static-sp.skoob.com.br/img/v2/logo-footer.png" style="margin-bottom: 5px;margin-right: 15px; width:70px;"/>
# </div>
# <div class="footer-info">
# Somos a maior rede social do Brasil criada especialmente para quem ama ler.
# Junte-se aos mais de 9 milhões de leitores e compartilhe experiências literárias.
# </div>
# </div>
# <div>
# <div class="footer-icons">
# <a alt="Facebook - Skoob" class="footer-icons-link" href="//www.facebook.com/skoobnews" target="_blank" title="Facebook - Skoob"><i class="fa fa-facebook-square"></i></a>
# <a alt="Youtube - Skoob" class="footer-icons-link" href="//www.youtube.com/user/skoobnews" target="_blank" title="Youtube - Skoob"><i class="fa fa-youtube-square"></i></a>
# <a alt="Twitter - Skoob" class="footer-icons-link" href="//twitter.com/skoobnews" rel="nofollow" target="_blank" title="Twitter - Skoob"><i class="fa fa-twitter-square"></i></a>
# <a alt="Instagram - Skoob" class="footer-icons-link" href="//instagram.com/skoobnews" rel="nofollow" target="_blank" title="Instagram - Skoob"><i class="fa fa-instagram"></i></a>
# </div>
# <div class="footer-icons-container">
# <div class="footer-app-stores">
# <h5 style="font-weight:600; margin:10px 0px !important; font-size: 14px;">Baixe nosso app</h5>
# <div class="apps">
# <a href="https://itunes.apple.com/br/app/skoob/id904670263?l=pt&amp;ls=1&amp;mt=8"><img alt="Baixe para iPhone" class="mb-2" src="https://static-sp.skoob.com.br/img/mkt/2015-SET/app-store.jpg" style="height:33px;"/></a>
# <a href="https://play.google.com/store/apps/details?id=com.gaudium.skoob&amp;hl=pt_BR"><img alt="Baixe para Android" class="mb-2" src="https://static-sp.skoob.com.br/img/mkt/2015-SET/google-play.jpg" style="height:33px;"/></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-links-icons-container">
# <div class="footer-links-container">
# <ul class="footer-ul">
# <li class="footer-li"><a class="footer-li-link" href="/ajuda/faq">FAQ</a></li>
# <li class="footer-li"><a class="footer-li-link" href="/inicio/quem_somos">Quem Somos</a></li>
# <li class="footer-li"><a class="footer-li-link" href="//blog.skoob.com.br/">Blog</a></li>
# <li class="footer-li"><a class="footer-li-link" href="/acervo/adicionar/">Cadastro de livros</a></li>
# <li class="footer-li"><a class="footer-li-link" href="/autor/checar/">Cadastro de autores</a></li>
# <li class="footer-li"><a class="footer-li-link" href="/downloads/">Downloads</a></li>
# <li class="footer-li"><a class="footer-li-link" href="/ajuda/faq">Fale Conosco</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-last-container">
# <div class="footer-last-links-container">
# <ul class="footer-last-ul">
# <li style="list-style: none;display: inline;padding: 0 12px;border-right: 1px solid #fff;font-size: 14px;margin: 0;"><a href="/livro/lista/" style="color:#fff;" title="Livros">Livros</a></li>
# <li style="list-style: none;display: inline;padding: 0 12px;border-right: 1px solid #fff;font-size: 14px;margin: 0;"><a href="/autor/recentes/" style="color:#fff;" title="Autores">Autores</a></li>
# <li style="list-style: none;display: inline;padding: 0 12px;border-right: 1px solid #fff;font-size: 14px;margin: 0;"><a href="/editoras/" style="color:#fff;" title="Editoras">Editoras</a></li>
# <li style="list-style: none;display: inline;padding: 0 12px;border-right: 1px solid #fff;font-size: 14px;margin: 0;"><a href="/usuario/lista" style="color:#fff;" title="Leitores">Leitores</a></li>
# <li style="list-style: none;display: inline;padding: 0 12px;border-right: 1px solid #fff;font-size: 14px;margin: 0;"><a href="/cortesia/" style="color:#fff;" title="Cortesias">Cortesias</a></li>
# <li style="list-style: none;display: inline;padding: 0 12px;border-right: 1px solid #fff;font-size: 14px;margin: 0;"><a href="/livro/lancamentos/" style="color:#fff;" title="Lançamentos">Lançamentos</a></li>
# <li style="list-style: none;display: inline;padding: 0 12px;border-right: 1px solid #fff;font-size: 14px;margin: 0;"><a href="/meta/ano/2023/" style="color:#fff;" title="Meta de Leitura">Meta de Leitura 2023</a></li>
# <li style="list-style: none;display: inline;padding: 0 12px;border-right: 1px solid #fff;font-size: 14px;margin: 0;"><a href="https://skoob-sp.s3-sa-east-1.amazonaws.com/app-files/termo_de_uso_skoob.pdf" style="color:#fff;" target="_blank" title="Termo de Uso">Termo de Uso</a></li>
# <li style="list-style: none;display: inline;padding: 0 12px;border-right: 0px solid #fff;font-size: 14px;margin: 0;"><a href="https://www.skoob.com.br/ajuda/privacidade" style="color:#fff;" target="_blank" title="Privacidade">Privacidade</a></li>
# </ul>
# </div>
# </div>
# </footer>
# <style>
#     .container-lgpd {
#         border-radius: 10px;
#         padding: 20px;
#         position: fixed;
#         bottom: 40px;
#         width: 250px;
#         display: flex;
#         flex-direction: column;
#         right: 50px;
#         border: #3189C8 solid 6px;
#         background-color: #fbf3bc;
#
#     }
#
#     .content-text-lgpd {
#         font-size: 15px;
#         color: #333;
#         margin-bottom: 15px;
#     }
#
#     .link-lgpd:link, .link-lgpd:hover, .link-lgpd:visited  {
#         font-size: 15px;
#         font-weight: normal;
#         color: #0069D9;
#     }
# </style>
# <div class="container-lgpd">
# <span class="content-text-lgpd">
# Utilizamos cookies e tecnologia para aprimorar sua experiência de navegação de acordo com a
# <a class="link-lgpd" href="https://www.skoob.com.br/ajuda/privacidade" target="_blank">
# Política de Privacidade.
# </a>
# </span>
# <a class="btn btn-success" href="?privacy-agree=true">ACEITAR</a>
# </div>
# </div></body>
# <script src="//www.google.com/jsapi" type="text/javascript"></script>
# <script type="text/javascript">
# _atrk_opts = { atrk_acct:"wIE9i1acVE00MP", domain:"skoob.com.br",dynamic: true};
# (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://www.skoob.com.br/js/alexa/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
# </script>
# <noscript><img alt="" height="1" src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=wIE9i1acVE00MP" style="display:none" width="1"/></noscript><script type="text/javascript"> var gaJsHost = (("https:" == document.location.protocol) ? "//ssl." : "//www.");
#                 document.write(unescape("%3Cscript src='" + gaJsHost + "google-analytics.com/ga.js' type='text/javascript'%3E%3C/script%3E"));</script>
# <script type="text/javascript">
#         var pageTracker = _gat._getTracker("UA-6452051-1");
#         pageTracker._trackPageview();
# </script> <script async="" src="//rtgpix.com/resources/scripts/src/pixel_skoob.js" type="text/javascript"></script>
# <script type="text/javascript">
# window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(13),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,-1!==o.indexOf("dev")&&(s.dev=!0),-1!==o.indexOf("nr_dev")&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,o){try{d?d-=1:i("err",[o||new UncaughtException(t,e,n)])}catch(s){try{i("ierr",[s,(new Date).getTime(),!0])}catch(c){}}return"function"==typeof f?f.apply(this,a(arguments)):!1}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t){i("err",[t,(new Date).getTime()])}var i=t("handle"),a=t(14),s=t("ee"),c=t("loader"),f=window.onerror,u=!1,d=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(l){"stack"in l&&(t(7),t(6),"addEventListener"in window&&t(4),c.xhrWrappable&&t(8),u=!0)}s.on("fn-start",function(t,e,n){u&&(d+=1)}),s.on("fn-err",function(t,e,n){u&&(this.thrown=!0,o(n))}),s.on("fn-end",function(){u&&!this.thrown&&d>0&&(d-=1)}),s.on("internal-error",function(t){i("ierr",[t,(new Date).getTime(),!0])})},{}],3:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(7),s=t(6);t("loader").features.stn=!0,t(5);var c=NREUM.o.EV;o.on("fn-start",function(t,e){var n=t[0];n instanceof c&&(this.bstStart=Date.now())}),o.on("fn-end",function(t,e){var n=t[0];n instanceof c&&i("bst",[n,e,this.bstStart,Date.now()])}),a.on("fn-start",function(t,e,n){this.bstStart=Date.now(),this.bstType=n}),a.on("fn-end",function(t,e){i("bstTimer",[e,this.bstStart,Date.now(),this.bstType])}),s.on("fn-start",function(){this.bstStart=Date.now()}),s.on("fn-end",function(t,e){i("bstTimer",[e,this.bstStart,Date.now(),"requestAnimationFrame"])}),o.on("pushState-start",function(t){this.time=Date.now(),this.startPath=location.pathname+location.hash}),o.on("pushState-end",function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),"addEventListener"in window.performance&&(window.performance.clearResourceTimings?window.performance.addEventListener("resourcetimingbufferfull",function(t){i("bstResource",[window.performance.getEntriesByType("resource")]),window.performance.clearResourceTimings()},!1):window.performance.addEventListener("webkitresourcetimingbufferfull",function(t){i("bstResource",[window.performance.getEntriesByType("resource")]),window.performance.webkitClearResourceTimings()},!1)),document.addEventListener("scroll",r,!1),document.addEventListener("keypress",r,!1),document.addEventListener("click",r,!1)}},{}],4:[function(t,e,n){function r(t){for(var e=t;e&&!e.hasOwnProperty(u);)e=Object.getPrototypeOf(e);e&&o(e)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,e){return t[1]}var a=t("ee").get("events"),s=t(15)(a),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";e.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,e){if(t[1]){var n=t[1];if("function"==typeof n){var r=c(n,"nr@wrapped",function(){return s(n,"fn-",null,n.name||"anonymous")});this.wrapped=t[1]=r}else"function"==typeof n.handleEvent&&s.inPlace(n,["handleEvent"],"fn-")}}),a.on(d+"-start",function(t){var e=this.wrapped;e&&(t[1]=e)})},{}],5:[function(t,e,n){var r=t("ee").get("history"),o=t(15)(r);e.exports=r,o.inPlace(wi ...
# ;NREUM.info={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",licenseKey:"9e53d555d8",applicationID:"17961617",sa:1}</script></html>

# %%
soup_renata.find_all(['li'], attrs = {'ng-repeat': 'livro in livros'})
# Out:
# []

# %%
soup_renata.find_all(['li'], attrs = {"class":"item-master"})[0].get('data-ng-repeat')
# Out:
# 'book in books'

# %%
soup_renata.find_all(['a'])[1].get('data-ng-href')
# Out:
# '/livro/{{book.livro_id}}ED{{book.id}}'

# %%
titulo = []
autor = []
ws_nota = []
ws_n_aval = []
ws_leram = []
ws_lendo = []
ws_querem_ler = []
ws_relendo = []
ws_abandonaram = []
ws_resenhas = []
ws_generos = []
ws_favoritos = []

for livro in mais_lidos:
    url_livro = f'https://www.skoob.com.br/{livro}'
    response_livro = requests.get(url_livro)
    html_livro = response_livro.content
    soup_livro = BeautifulSoup(html_livro)
    
    titulo += [str(soup_livro.find_all('title')[0])[7:-8].split(" - ")[0]]
    autor += [str(soup_livro.find_all('title')[0])[7:-8].split(" - ")[1]]
    ws_nota += [soup_livro.find_all(['star-rating'], attrs = {"size":"medium"})[0].get("rate")]
    ws_n_aval += [soup_livro.find_all(['div'], attrs = {"id":"pg-livro-box-rating-avaliadores-numero"})[0].text.split(" ")[0]]
    ws_leram += [soup_livro.find_all(['b'])[6].text]
    ws_lendo += [soup_livro.find_all(['b'])[5].text]
    ws_querem_ler += [soup_livro.find_all(['b'])[4].text]
    ws_relendo += [soup_livro.find_all(['b'])[3].text]
    ws_abandonaram += [soup_livro.find_all(['b'])[2].text]
    ws_resenhas += [soup_livro.find_all(['b'])[1].text]
    ws_generos += [soup_livro.find_all(['span'], attrs = {"class" : "pg-livro-generos"})[0].text]
    ws_favoritos += [soup_livro.find_all(['div','a'], attrs = {"class":"link_11_off l_icones sk-cor-branco"})[0].text.split(" ")[-1]]

# %%
nota = [float(n) for n in ws_nota]
n_aval = [int(i.replace(".","")) for i in ws_n_aval]
leram = [int(i.replace(".","")) for i in ws_leram]
lendo = [int(i.replace(".","")) for i in ws_lendo]
querem_ler = [int(i.replace(".","")) for i in ws_querem_ler]
relendo = [int(i.replace(".","")) for i in ws_relendo]
abandonaram = [int(i.replace(".","")) for i in ws_abandonaram]
resenhas = [int(i.replace(".","")) for i in ws_resenhas]
favoritos = [int(i.replace("(","").replace(")","").replace(".","")) for i in ws_favoritos]

df_mais_lidos = pd.DataFrame({"titulo" : titulo,
                         "autor" : autor,
                         "genero" : ws_generos,
                         "nota" : nota,
                         "n_aval" : n_aval,
                         "leram" : leram,
                         "lendo" : lendo,
                         "querem_ler" : querem_ler,
                         "relendo" : relendo,
                         "abandonaram" : abandonaram,
                         "favoritos" : favoritos,
                         "n_resenhas" : resenhas})
df_mais_lidos['mais_lidos'] = df_mais_lidos.index + 1

# %%
df_mais_lidos

# %%
rank_mais_lidos = df_mais_lidos[['titulo','mais_lidos']]
rank_mais_lidos

# %%
#rank_mais_lidos.to_csv('rank_mais_lidos.csv', index = False)

# %%
#df_mais_lidos.to_csv('mais_lidos.csv', index = False)

# %% [markdown]
# # Mais Lendo

# %%
url_mais_lendo = 'https://www.skoob.com.br/livro/top_mais/lendo/'
response_mais_lendo = requests.get(url_mais_lendo)
html_mais_lendo = response_mais_lendo.content
soup_mais_lendo = BeautifulSoup(html_mais_lendo)

# %%
mais_lendo = [soup_mais_lendo.find_all(['a'], attrs = {"target" : "_blank"})[i].get('href') for i in range(106)]

# %%
mais_lendo

# %%
titulo = []
autor = []
ws_nota = []
ws_n_aval = []
ws_leram = []
ws_lendo = []
ws_querem_ler = []
ws_relendo = []
ws_abandonaram = []
ws_resenhas = []
ws_generos = []
ws_favoritos = []

for livro in mais_lendo:
    url_livro = f'https://www.skoob.com.br/{livro}'
    response_livro = requests.get(url_livro)
    html_livro = response_livro.content
    soup_livro = BeautifulSoup(html_livro)
    
    titulo += [str(soup_livro.find_all('title')[0])[7:-8].split(" - ")[0]]
    autor += [str(soup_livro.find_all('title')[0])[7:-8].split(" - ")[1]]
    ws_nota += [soup_livro.find_all(['star-rating'], attrs = {"size":"medium"})[0].get("rate")]
    ws_n_aval += [soup_livro.find_all(['div'], attrs = {"id":"pg-livro-box-rating-avaliadores-numero"})[0].text.split(" ")[0]]
    ws_leram += [soup_livro.find_all(['b'])[6].text]
    ws_lendo += [soup_livro.find_all(['b'])[5].text]
    ws_querem_ler += [soup_livro.find_all(['b'])[4].text]
    ws_relendo += [soup_livro.find_all(['b'])[3].text]
    ws_abandonaram += [soup_livro.find_all(['b'])[2].text]
    ws_resenhas += [soup_livro.find_all(['b'])[1].text]
    ws_generos += [soup_livro.find_all(['span'], attrs = {"class" : "pg-livro-generos"})[0].text]
    ws_favoritos += [soup_livro.find_all(['div','a'], attrs = {"class":"link_11_off l_icones sk-cor-branco"})[0].text.split(" ")[-1]]

# %%
nota = [float(n) for n in ws_nota]
n_aval = [int(i.replace(".","")) for i in ws_n_aval]
leram = [int(i.replace(".","")) for i in ws_leram]
lendo = [int(i.replace(".","")) for i in ws_lendo]
querem_ler = [int(i.replace(".","")) for i in ws_querem_ler]
relendo = [int(i.replace(".","")) for i in ws_relendo]
abandonaram = [int(i.replace(".","")) for i in ws_abandonaram]
resenhas = [int(i.replace(".","")) for i in ws_resenhas]
favoritos = [int(i.replace("(","").replace(")","").replace(".","")) for i in ws_favoritos]

df_mais_lendo = pd.DataFrame({"titulo" : titulo,
                         "autor" : autor,
                         "genero" : ws_generos,
                         "nota" : nota,
                         "n_aval" : n_aval,
                         "leram" : leram,
                         "lendo" : lendo,
                         "querem_ler" : querem_ler,
                         "relendo" : relendo,
                         "abandonaram" : abandonaram,
                         "favoritos" : favoritos,
                         "n_resenhas" : resenhas})
df_mais_lendo['mais_lendo'] = df_mais_lendo.index + 1

# %%
df_mais_lendo

# %%
rank_mais_lendo = df_mais_lendo[['titulo','mais_lendo']]
rank_mais_lendo

# %%
#rank_mais_lendo.to_csv('rank_mais_lendo.csv', index = False)

# %%
#df_mais_lendo.to_csv('mais_lendo.csv', index = False)

# %% [markdown]
# # Mais Quero Ler

# %%
url_mais_quero_ler = 'https://www.skoob.com.br/livro/top_mais/queroler/'
response_mais_quero_ler = requests.get(url_mais_quero_ler)
html_mais_quero_ler = response_mais_quero_ler.content
soup_mais_quero_ler = BeautifulSoup(html_mais_quero_ler)

# %%
mais_quero_ler = [soup_mais_quero_ler.find_all(['a'], attrs = {"target" : "_blank"})[i].get('href') for i in range(106)]

# %%
titulo = []
autor = []
ws_nota = []
ws_n_aval = []
ws_leram = []
ws_lendo = []
ws_querem_ler = []
ws_relendo = []
ws_abandonaram = []
ws_resenhas = []
ws_generos = []
ws_favoritos = []

for livro in mais_quero_ler:
    url_livro = f'https://www.skoob.com.br/{livro}'
    response_livro = requests.get(url_livro)
    html_livro = response_livro.content
    soup_livro = BeautifulSoup(html_livro)
    
    titulo += [str(soup_livro.find_all('title')[0])[7:-8].split(" - ")[0]]
    autor += [str(soup_livro.find_all('title')[0])[7:-8].split(" - ")[1]]
    ws_nota += [soup_livro.find_all(['star-rating'], attrs = {"size":"medium"})[0].get("rate")]
    ws_n_aval += [soup_livro.find_all(['div'], attrs = {"id":"pg-livro-box-rating-avaliadores-numero"})[0].text.split(" ")[0]]
    ws_leram += [soup_livro.find_all(['b'])[6].text]
    ws_lendo += [soup_livro.find_all(['b'])[5].text]
    ws_querem_ler += [soup_livro.find_all(['b'])[4].text]
    ws_relendo += [soup_livro.find_all(['b'])[3].text]
    ws_abandonaram += [soup_livro.find_all(['b'])[2].text]
    ws_resenhas += [soup_livro.find_all(['b'])[1].text]
    ws_generos += [soup_livro.find_all(['span'], attrs = {"class" : "pg-livro-generos"})[0].text]
    ws_favoritos += [soup_livro.find_all(['div','a'], attrs = {"class":"link_11_off l_icones sk-cor-branco"})[0].text.split(" ")[-1]]

# %%
nota = [float(n) for n in ws_nota]
n_aval = [int(i.replace(".","")) for i in ws_n_aval]
leram = [int(i.replace(".","")) for i in ws_leram]
lendo = [int(i.replace(".","")) for i in ws_lendo]
querem_ler = [int(i.replace(".","")) for i in ws_querem_ler]
relendo = [int(i.replace(".","")) for i in ws_relendo]
abandonaram = [int(i.replace(".","")) for i in ws_abandonaram]
resenhas = [int(i.replace(".","")) for i in ws_resenhas]
favoritos = [int(i.replace("(","").replace(")","").replace(".","")) for i in ws_favoritos]

df_mais_quero_ler = pd.DataFrame({"titulo" : titulo,
                         "autor" : autor,
                         "genero" : ws_generos,
                         "nota" : nota,
                         "n_aval" : n_aval,
                         "leram" : leram,
                         "lendo" : lendo,
                         "querem_ler" : querem_ler,
                         "relendo" : relendo,
                         "abandonaram" : abandonaram,
                         "favoritos" : favoritos,
                         "n_resenhas" : resenhas})
df_mais_quero_ler['mais_quero_ler'] = df_mais_quero_ler.index + 1

# %%
df_mais_quero_ler

# %%
rank_mais_quero_ler = df_mais_quero_ler[['titulo','mais_quero_ler']]
rank_mais_quero_ler

# %%
#rank_mais_quero_ler.to_csv('rank_mais_quero_ler.csv', index = False)

# %%
#df_mais_quero_ler.to_csv('mais_quero_ler.csv', index = False)

# %% [markdown]
# # Mais Abandonados

# %%
url_mais_abondonados = 'https://www.skoob.com.br/livro/top_mais/abandonados/'
response_mais_abondonados = requests.get(url_mais_abondonados)
html_mais_abondonados = response_mais_abondonados.content
soup_mais_abondonados = BeautifulSoup(html_mais_abondonados)

# %%
mais_abondonados = [soup_mais_abondonados.find_all(['a'], attrs = {"target" : "_blank"})[i].get('href') for i in range(106)]

# %%
titulo = []
autor = []
ws_nota = []
ws_n_aval = []
ws_leram = []
ws_lendo = []
ws_querem_ler = []
ws_relendo = []
ws_abandonaram = []
ws_resenhas = []
ws_generos = []
ws_favoritos = []

for livro in mais_abondonados:
    url_livro = f'https://www.skoob.com.br/{livro}'
    response_livro = requests.get(url_livro)
    html_livro = response_livro.content
    soup_livro = BeautifulSoup(html_livro)
    
    titulo += [str(soup_livro.find_all('title')[0])[7:-8].split(" - ")[0]]
    autor += [str(soup_livro.find_all('title')[0])[7:-8].split(" - ")[-1]]
    ws_nota += [soup_livro.find_all(['star-rating'], attrs = {"size":"medium"})[0].get("rate")]
    ws_n_aval += [soup_livro.find_all(['div'], attrs = {"id":"pg-livro-box-rating-avaliadores-numero"})[0].text.split(" ")[0]]
    ws_leram += [soup_livro.find_all(['b'])[6].text]
    ws_lendo += [soup_livro.find_all(['b'])[5].text]
    ws_querem_ler += [soup_livro.find_all(['b'])[4].text]
    ws_relendo += [soup_livro.find_all(['b'])[3].text]
    ws_abandonaram += [soup_livro.find_all(['b'])[2].text]
    ws_resenhas += [soup_livro.find_all(['b'])[1].text]
    ws_generos += [soup_livro.find_all(['span'], attrs = {"class" : "pg-livro-generos"})[0].text]
    ws_favoritos += [soup_livro.find_all(['div','a'], attrs = {"class":"link_11_off l_icones sk-cor-branco"})[0].text.split(" ")[-1]]

# %%
nota = [float(n) for n in ws_nota]
n_aval = [int(i.replace(".","")) for i in ws_n_aval]
leram = [int(i.replace(".","")) for i in ws_leram]
lendo = [int(i.replace(".","")) for i in ws_lendo]
querem_ler = [int(i.replace(".","")) for i in ws_querem_ler]
relendo = [int(i.replace(".","")) for i in ws_relendo]
abandonaram = [int(i.replace(".","")) for i in ws_abandonaram]
resenhas = [int(i.replace(".","")) for i in ws_resenhas]
favoritos = [int(i.replace("(","").replace(")","").replace(".","")) for i in ws_favoritos]

df_mais_abondonados = pd.DataFrame({"titulo" : titulo,
                         "autor" : autor,
                         "genero" : ws_generos,
                         "nota" : nota,
                         "n_aval" : n_aval,
                         "leram" : leram,
                         "lendo" : lendo,
                         "querem_ler" : querem_ler,
                         "relendo" : relendo,
                         "abandonaram" : abandonaram,
                         "favoritos" : favoritos,
                         "n_resenhas" : resenhas})
df_mais_abondonados['mais_abondonados'] = df_mais_abondonados.index + 1

# %%
df_mais_abondonados

# %%
rank_mais_abandonados = df_mais_abondonados[['titulo','mais_abondonados']]
rank_mais_abandonados

# %%
#rank_mais_abandonados.to_csv('rank_mais_abandonados.csv', index = False)

# %%
#df_mais_abondonados.to_csv('mais_abondonados.csv', index = False)

# %% [markdown]
# # Mais Desejados

# %%
url_mais_desejados = 'https://www.skoob.com.br/livro/top_mais/desejados/'
response_mais_desejados = requests.get(url_mais_desejados)
html_mais_desejados = response_mais_desejados.content
soup_mais_desejados = BeautifulSoup(html_mais_desejados)

# %%
mais_desejados = [soup_mais_desejados.find_all(['a'], attrs = {"target" : "_blank"})[i].get('href') for i in range(106)]

# %%
titulo = []
autor = []
ws_nota = []
ws_n_aval = []
ws_leram = []
ws_lendo = []
ws_querem_ler = []
ws_relendo = []
ws_abandonaram = []
ws_resenhas = []
ws_generos = []
ws_favoritos = []

for livro in mais_desejados:
    url_livro = f'https://www.skoob.com.br/{livro}'
    response_livro = requests.get(url_livro)
    html_livro = response_livro.content
    soup_livro = BeautifulSoup(html_livro)
    
    titulo += [str(soup_livro.find_all('title')[0])[7:-8].split(" - ")[0]]
    autor += [str(soup_livro.find_all('title')[0])[7:-8].split(" - ")[-1]]
    ws_nota += [soup_livro.find_all(['star-rating'], attrs = {"size":"medium"})[0].get("rate")]
    ws_n_aval += [soup_livro.find_all(['div'], attrs = {"id":"pg-livro-box-rating-avaliadores-numero"})[0].text.split(" ")[0]]
    ws_leram += [soup_livro.find_all(['b'])[6].text]
    ws_lendo += [soup_livro.find_all(['b'])[5].text]
    ws_querem_ler += [soup_livro.find_all(['b'])[4].text]
    ws_relendo += [soup_livro.find_all(['b'])[3].text]
    ws_abandonaram += [soup_livro.find_all(['b'])[2].text]
    ws_resenhas += [soup_livro.find_all(['b'])[1].text]
    ws_generos += [soup_livro.find_all(['span'], attrs = {"class" : "pg-livro-generos"})[0].text]
    ws_favoritos += [soup_livro.find_all(['div','a'], attrs = {"class":"link_11_off l_icones sk-cor-branco"})[0].text.split(" ")[-1]]

# %%
nota = [float(n) for n in ws_nota]
n_aval = [int(i.replace(".","")) for i in ws_n_aval]
leram = [int(i.replace(".","")) for i in ws_leram]
lendo = [int(i.replace(".","")) for i in ws_lendo]
querem_ler = [int(i.replace(".","")) for i in ws_querem_ler]
relendo = [int(i.replace(".","")) for i in ws_relendo]
abandonaram = [int(i.replace(".","")) for i in ws_abandonaram]
resenhas = [int(i.replace(".","")) for i in ws_resenhas]
favoritos = [int(i.replace("(","").replace(")","").replace(".","")) for i in ws_favoritos]

df_mais_desejados = pd.DataFrame({"titulo" : titulo,
                         "autor" : autor,
                         "genero" : ws_generos,
                         "nota" : nota,
                         "n_aval" : n_aval,
                         "leram" : leram,
                         "lendo" : lendo,
                         "querem_ler" : querem_ler,
                         "relendo" : relendo,
                         "abandonaram" : abandonaram,
                         "favoritos" : favoritos,
                         "n_resenhas" : resenhas})
df_mais_desejados['mais_desejados'] = df_mais_desejados.index + 1

# %%
df_mais_desejados

# %%
rank_mais_desejados = df_mais_desejados[['titulo','mais_desejados']]
rank_mais_desejados

# %%
#rank_mais_desejados.to_csv('rank_mais_desejados.csv', index = False)

# %%
#df_mais_desejados.to_csv('mais_desejados.csv', index = False)

# %% [markdown]
# # Mais Favoritos

# %%
url_mais_favoritos = 'https://www.skoob.com.br/livro/top_mais/favoritos/'
response_mais_favoritos = requests.get(url_mais_favoritos)
html_mais_favoritos = response_mais_favoritos.content
soup_mais_favoritos = BeautifulSoup(html_mais_favoritos)

# %%
mais_favoritos = [soup_mais_favoritos.find_all(['a'], attrs = {"target" : "_blank"})[i].get('href') for i in range(106)]

# %%
titulo = []
autor = []
ws_nota = []
ws_n_aval = []
ws_leram = []
ws_lendo = []
ws_querem_ler = []
ws_relendo = []
ws_abandonaram = []
ws_resenhas = []
ws_generos = []
ws_favoritos = []

for livro in mais_favoritos:
    url_livro = f'https://www.skoob.com.br/{livro}'
    response_livro = requests.get(url_livro)
    html_livro = response_livro.content
    soup_livro = BeautifulSoup(html_livro)
    
    titulo += [str(soup_livro.find_all('title')[0])[7:-8].split(" - ")[0]]
    autor += [str(soup_livro.find_all('title')[0])[7:-8].split(" - ")[-1]]
    ws_nota += [soup_livro.find_all(['star-rating'], attrs = {"size":"medium"})[0].get("rate")]
    ws_n_aval += [soup_livro.find_all(['div'], attrs = {"id":"pg-livro-box-rating-avaliadores-numero"})[0].text.split(" ")[0]]
    ws_leram += [soup_livro.find_all(['b'])[6].text]
    ws_lendo += [soup_livro.find_all(['b'])[5].text]
    ws_querem_ler += [soup_livro.find_all(['b'])[4].text]
    ws_relendo += [soup_livro.find_all(['b'])[3].text]
    ws_abandonaram += [soup_livro.find_all(['b'])[2].text]
    ws_resenhas += [soup_livro.find_all(['b'])[1].text]
    ws_generos += [soup_livro.find_all(['span'], attrs = {"class" : "pg-livro-generos"})[0].text]
    ws_favoritos += [soup_livro.find_all(['div','a'], attrs = {"class":"link_11_off l_icones sk-cor-branco"})[0].text.split(" ")[-1]]

# %%
nota = [float(n) for n in ws_nota]
n_aval = [int(i.replace(".","")) for i in ws_n_aval]
leram = [int(i.replace(".","")) for i in ws_leram]
lendo = [int(i.replace(".","")) for i in ws_lendo]
querem_ler = [int(i.replace(".","")) for i in ws_querem_ler]
relendo = [int(i.replace(".","")) for i in ws_relendo]
abandonaram = [int(i.replace(".","")) for i in ws_abandonaram]
resenhas = [int(i.replace(".","")) for i in ws_resenhas]
favoritos = [int(i.replace("(","").replace(")","").replace(".","")) for i in ws_favoritos]

df_mais_favoritos = pd.DataFrame({"titulo" : titulo,
                         "autor" : autor,
                         "genero" : ws_generos,
                         "nota" : nota,
                         "n_aval" : n_aval,
                         "leram" : leram,
                         "lendo" : lendo,
                         "querem_ler" : querem_ler,
                         "relendo" : relendo,
                         "abandonaram" : abandonaram,
                         "favoritos" : favoritos,
                         "n_resenhas" : resenhas})
df_mais_favoritos['mais_favoritos'] = df_mais_favoritos.index + 1

# %%
df_mais_favoritos

# %%
rank_mais_favoritos = df_mais_favoritos[['titulo','mais_favoritos']]
rank_mais_favoritos

# %%
#rank_mais_favoritos.to_csv('rank_mais_favoritos.csv', index = False)

# %%
#df_mais_favoritos.to_csv('mais_favoritos.csv', index = False)

# %% [markdown]
# # Data frame único

# %%
df_all_concat.shape

# %%
df_all_concat = pd.concat([df_mais_lidos, df_mais_lendo, df_mais_quero_ler,df_mais_abondonados,df_mais_desejados,df_mais_favoritos])
df_all_concat

# %%
df_all_concat[df_all_concat['titulo'] == 'Harry Potter e a Pedra Filosofal (Harry Potter #1)']

# %%
df_all = df_all_concat.drop_duplicates(subset = ['titulo'], keep='last')
df_all

# %%
df_all = pd.merge(df_all, rank_mais_lidos, how = 'left', on = 'titulo' )
df_all = pd.merge(df_all, rank_mais_lendo, how = 'left', on = 'titulo' )
df_all = pd.merge(df_all, rank_mais_quero_ler, how = 'left', on = 'titulo' )
df_all = pd.merge(df_all, rank_mais_abandonados, how = 'left', on = 'titulo' )
df_all = pd.merge(df_all, rank_mais_desejados, how = 'left', on = 'titulo' )
df_all = pd.merge(df_all, rank_mais_favoritos, how = 'left', on = 'titulo' )
df_all

# %%
df_all

# %%
df_all.loc[df_all['genero']=='Ficção / Literatura Estrangeira / Romance',:]

# %%
df_all.loc[df_all['autor']=='Agatha Christie',:]

# %%
df_all['genero'][0]

# %%
pat = 'Aventura / Fantasia / Ficção / Infantojuvenil / Jovem adulto / Literatura Estrangeira / Romance '
df_all['genero'].isin([pat])

# %%
pattern = 'Infantil'
df_all['genero'].isin([pattern]).value_counts()

# %%
pat = '.*Fantasia.*'
df_all['genero'].str.contains(pat)
